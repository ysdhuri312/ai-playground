# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5])
arr1
type(arr1)

# %%
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
arr2

# %%
arr3 = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])
arr3

# %%
arr3 = np.zeros((2,3))
arr3

# %%
arr4 = np.ones((2,3))
arr4

# %%
arr5 = np.identity(5)
arr5

# %%
arr6 = np.arange(10)
arr6

# %%
arr6.size

# %%
arr6.itemsize

# %%
arr5.itemsize

# %%
lista = range(100)

# %%
arr7 = np.arange(100)

# %%
import sys

# %%
print(sys.getsizeof(87)*len(lista))

# %%
print(arr7.size*arr7.itemsize)

# %%
arr8 = np.arange(24).reshape(6,4)
arr8

# %%
arr8[3:5,1:3]

# %%
arr8[4:,2:]

# %%
arr8[4,2]

# %%
arr8[4][2]

# %%
for i in np.nditer(arr8):
  print(i)

# %%
arr10 = np.arange(8).reshape(4,2)
arr10

# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
np.stack((a,b))

# %%
np.stack((a, b), axis=1)

# %%
arr11 = np.arange(24).reshape(6,4)
arr11

# %%
arr11[[0,2,5]]

# %%
arr12 = np.random.randint(low=1,high=99,size=20).reshape(4,5)
arr12

# %%
arr12[arr12>40]

# %%
arr12[(arr12>40) & (arr12%2 != 0)] = 0

# %%
arr12

# %%
arr13 = np.linspace(-40,40,100)
arr13

# %%
arr14 = np.sin(arr13)

# %%
arr14

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(arr13,arr14)

# %%
np.random.randint(1,10,6).reshape(3,2)
